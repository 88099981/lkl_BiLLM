# %%
import torch
import os
import torch.nn as nn
import numpy as np
from utils.data_visualization import difference_fp32_16, create_tensor_img, difference_ratio

# %%
基本是三位数字后才会有差异

# %%
x=torch.tensor([1.2547,0.2145,3.21498],dtype=torch.float16)
xx=x.to(torch.float32)
y=torch.rand((3),dtype=torch.float16)
yy=y.to(torch.float32)
print(f'x: {x}\nxx: {xx}\ny: {y}\nyy: {yy}\n')
z=x/y
zz=xx/yy
print(f'z: {z}\nzz:{zz}\nz==zz? {z==zz}')
# Out:
# x: tensor([1.2549, 0.2145, 3.2148], dtype=torch.float16)
# xx: tensor([1.2549, 0.2145, 3.2148])
# y: tensor([0.7598, 0.3179, 0.7749], dtype=torch.float16)
# yy: tensor([0.7598, 0.3179, 0.7749])
#
# z: tensor([1.6514, 0.6748, 4.1484], dtype=torch.float16)
# zz:tensor([1.6517, 0.6747, 4.1487])
# z==zz? tensor([False, False, False])

# %%
#difference_img
load_path_32='/home/liukunlong/lkl_BiLLM/output/llama_float32_c4/pth/test/'
load_path_16='/home/liukunlong/lkl_BiLLM/output/llama_float16_c4/pth/test/'
save_path='/home/liukunlong/lkl_BiLLM/output/img/test/'

if not os.path.exists(save_path):
    os.makedirs(save_path)

# 遍历文件夹中的所有文件
for filename in os.listdir(load_path_32):
    # 检查是否为文件（排除文件夹）
    
    if os.path.isfile(os.path.join(load_path_32, filename)):
        # 打印原始文件名
        print(f"原始文件名: {filename}")
        difference_ratio(
            fp32_path=os.path.join(load_path_32, filename),
            fp16_path=os.path.join(load_path_16, filename),
            save_name=filename,
            save_path=save_path
        )
# Out:
# 原始文件名: 30_self_attn.v_proj.pth
# /home/liukunlong/lkl_BiLLM/utils/data_visualization.py:73: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
#tensor_img
load_path_32='/home/liukunlong/lkl_BiLLM/output/llama_float32_c4/pth'
load_path_16='/home/liukunlong/lkl_BiLLM/output/llama_float16_c4/pth'
save_path_32='/home/liukunlong/lkl_BiLLM/output/llama_float32_c4/img'
save_path_16='/home/liukunlong/lkl_BiLLM/output/llama_float16_c4/img'

load_path=load_path_16
save_path=save_path_16

if not os.path.exists(save_path):
    os.makedirs(save_path)

# 遍历文件夹中的所有文件
for filename in os.listdir(load_path):
    # 检查是否为文件（排除文件夹）
    
    if os.path.isfile(os.path.join(load_path, filename)):
        # 打印原始文件名
        print(f"原始文件名: {filename}")
        create_tensor_img(
            tensor_path=os.path.join(load_path, filename),
            save_name=filename,
            save_path=save_path
        )
# Out:
# 原始文件名: 18_mlp.down_proj_hinv.pth
# /home/liukunlong/lkl_BiLLM/utils/data_visualization.py:42: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

# 创建一个3D图形
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# 生成一些3D数据
x = np.linspace(-5, 5, 50)
y = np.linspace(-5, 5, 50)
x, y = np.meshgrid(x, y)
z = np.sin(np.sqrt(x**2 + y**2))

# 绘制曲面
ax.plot_surface(x, y, z, cmap='viridis')

# 设置视角
ax.view_init(elev=20, azim=30)  # 仰角为30度，方位角为120度

# 显示图形
plt.show()

# %%
load_path_32='/home/liukunlong/lkl_BiLLM/output/llama_float32_c4/pth/0_mlp.gate_proj.pth'
load_path_16='/home/liukunlong/lkl_BiLLM/output/llama_float16_c4/pth/0_mlp.gate_proj.pth'
tensor_32=torch.load(load_path_32)
tensor_16=torch.load(load_path_16)
# Out:
# /tmp/ipykernel_620204/2627706931.py:3: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   tensor_32=torch.load(load_path_32)
# ...

# %%
load_path_32='/home/liukunlong/lkl_BiLLM/output/llama_float32_c4/pth/25_mlp.up_proj_hinv.pth'
load_path_16='/home/liukunlong/lkl_BiLLM/output/llama_float16_c4/pth/25_mlp.up_proj_hinv.pth'

fp32_tensor = torch.load(load_path_32)
fp16_tensor = torch.load(load_path_16)
fp32_tensor
# Out:
# /tmp/ipykernel_3947966/2074878719.py:4: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   fp32_tensor = torch.load(load_path_32)
# ...

# %%
fp32_tensor.mean()
# Out:
# tensor(2.2012e-05, device='cuda:6')

# %%
fp16_tensor.mean()
# Out:
# tensor(2.2133e-05, device='cuda:6')

# %%
fp16_tensor-fp32_tensor
# Out:
# tensor([[-3.6424e-04, -3.0552e-04,  1.3963e-03,  ..., -9.4669e-04,
#          -6.6898e-04, -1.0088e-03],
#         [ 0.0000e+00, -8.7248e-04,  7.8719e-04,  ..., -1.2218e-03,
#           1.1812e-03, -1.4892e-04],
#         [ 0.0000e+00,  0.0000e+00, -3.1647e-04,  ...,  2.2573e-03,
#           4.3720e-05,  1.2850e-04],
#         ...,
#         [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  ..., -3.6767e-04,
#          -2.7407e-04,  3.9430e-03],
#         [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  ...,  0.0000e+00,
#           7.1755e-03,  1.7003e-03],
#         [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  ...,  0.0000e+00,
#           0.0000e+00, -3.1044e-03]], device='cuda:6')
